# %%
data=pd.read_csv("Salary_Data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data=pd.read_csv("Salary_Data")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
data=pd.read_csv("Salary_Data")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data=pd.read_csv("Salary_Data")
#
# NameError: name 'pd' is not defined
